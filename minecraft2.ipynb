# %%
library(tidyverse)

# %%
playerdata <- read_csv("players.csv")
sessionsdata <- read_csv("sessions.csv")
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1535 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): hashedEmail, start_time, end_time
# dbl (2): original_start_time, original_end_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# **(1) Data Description:**

# %%
head(playerdata)
# Out:
#   experience subscribe
# 1 Pro         TRUE
# 2 Veteran     TRUE
# 3 Veteran    FALSE
# 4 Amateur     TRUE
# 5 Regular     TRUE
# 6 Amateur     TRUE
#   hashedEmail                                                      played_hours
# 1 f6daba428a5e19a3d47574858c13550499be23603422e6a0ee9728f8b53e192d 30.3
# 2 f3c813577c458ba0dfef80996f8f32c93b6e8af1fa939732842f2312358a88e9  3.8
# 3 b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3c5a9d2118eb7ccbb28  0.0
# 4 23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4fa7a5a659ff443a0eb5  0.7
# 5 7dc01f10bf20671ecfccdac23812b1b415acd42c2147cb0af4d48fcce2420f3e  0.1
# 6 f58aad5996a435f16b0284a3b267f973f9af99e7a89bee0430055a44fa92f977  0.0
#   name      gender Age
# 1 Morgan    Male    9
# 2 Christian Male   17
# 3 Blake     Male   17
# 4 Flora     Female 21
# 5 Kylie     Male   21
# 6 Adrian    Female 17

# %% [markdown]
# In the dataset "players.csv", there are:
#
# Rows/Observations: 196 - The number of particpants' involved in study
#
# Columns/Variables: 7 - The different variables pertaining to each particpant, including:
#
# ***Numerical Type Variables - "dbl"***:
#
# (1) ***played_hours***: Total hours spent on Minecraft.
#
# (2) ***Age****: Age of particpant.
#
# ***Character Type Variables - "chr"***:
#
# (3) ***hashedEmail***: Email of participants, hashed for privacy.
#
# (4) ***name***: Name of participant.
#
# (5) ***gender***: Gender of particpant.
#
# (6) ***experience***: Skill level ranging between: (Beginner, Amateur, Regular, Veteran, Pro)
#
# ***Logical Type Variables - "lgl"***
#
# (7) ***subscribe***: Status of subscription to newsletter.
#
# *An error for this dataset, is that Age is classifed as **dbl**, instead of **int**, since it doesn't include any decimals.

# %%
head(sessionsdata)
# Out:
#   hashedEmail
# 1 bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 2 36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 3 f8f5477f5a2e53616ae37421b1c660b971192bd8ff77e3398304c7ae42581fdc
# 4 bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 5 36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 6 bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
#   start_time       end_time         original_start_time original_end_time
# 1 30/06/2024 18:12 30/06/2024 18:24 1.71977e+12         1.71977e+12
# 2 17/06/2024 23:33 17/06/2024 23:46 1.71867e+12         1.71867e+12
# 3 25/07/2024 17:34 25/07/2024 17:57 1.72193e+12         1.72193e+12
# 4 25/07/2024 03:22 25/07/2024 03:58 1.72188e+12         1.72188e+12
# 5 25/05/2024 16:01 25/05/2024 16:12 1.71665e+12         1.71665e+12
# 6 23/06/2024 15:08 23/06/2024 17:10 1.71916e+12         1.71916e+12

# %% [markdown]
# In the "sessions.csv",  there are:
#
# Rows/Observations: 1535 - number of sessions recorded
#
# Columns/Variables: 5 - The different variables pertaining to each particpant, including:
#
# ***Character Type Variables***
#
# (1) ***hashedEmail***: Email of participants, hashed for privacy.
#
# (2) ***start_time***: Start of gaming session including date and time(hours).
#
# (3) ***end_time***: End of gaming session including data and time(hours).
#
# ***Numerical Type Variables - "dbl"***
#
# (4) ***Original_start_time:*** - Start of gaming session in miliseconds
#
# (5) ***Original_end_time:*** - End of gaming session in miliseconds

# %%
#In the dataset, the mean of the numerical variables can be found using: 

playedhrs_mean <- summarize(playerdata, "Mean Hours Played" = mean(played_hours))|>
round(2)

age_mean <- summarize(playerdata, "Mean Age" = mean(Age, na.rm = TRUE))|>
round(2)

playedhrs_mean
age_mean

#Additionally, we can use the summarize function to see an overivew of the datasets to better help us tidy them later.

playersummary <- summary(playerdata)
playersummary
# Out:
#   Mean Hours Played
# 1 5.85
#   Mean Age
# 1 21.14
#   experience        subscribe       hashedEmail         played_hours
#  Length:196         Mode :logical   Length:196         Min.   :  0.000
#  Class :character   FALSE:52        Class :character   1st Qu.:  0.000
#  Mode  :character   TRUE :144       Mode  :character   Median :  0.100
#                                                        Mean   :  5.846
#                                                        3rd Qu.:  0.600
#                                                        Max.   :223.100
#
#      name              gender               Age
#  Length:196         Length:196         Min.   : 9.00
#  Class :character   Class :character   1st Qu.:17.00
#  Mode  :character   Mode  :character   Median :19.00
#                                        Mean   :21.14
#                                        3rd Qu.:22.75
#                                        Max.   :58.00
#                                        NA's   :2

# %%
sessionsummary <- summary(sessionsdata)
sessionsummary
# Out:
#  hashedEmail         start_time          end_time         original_start_time
#  Length:1535        Length:1535        Length:1535        Min.   :1.712e+12
#  Class :character   Class :character   Class :character   1st Qu.:1.716e+12
#  Mode  :character   Mode  :character   Mode  :character   Median :1.719e+12
#                                                           Mean   :1.719e+12
#                                                           3rd Qu.:1.722e+12
#                                                           Max.   :1.727e+12
#
#  original_end_time
#  Min.   :1.712e+12
#  1st Qu.:1.716e+12
#  Median :1.719e+12
#  Mean   :1.719e+12
#  3rd Qu.:1.722e+12
#  Max.   :1.727e+12
#  NA's   :2

# %% [markdown]
# **(2) Questions:**
#
#
# **Question 1: What player characteristics and behaviours are most predictive of subscribing to a game-related newsletter, and how do these features differ between various player types?**

# %% [markdown]
# ***Can a player’s experience level and total playtime predict whether they subscribe to a game-related newsletter in players.csv?***
#
# I chose to use "experience level" and "total playtime" as predictors because I believe that they effectively demonstrate the users skill and engagement. I believe that a combination of these two contribute to their reasoning for subscribing to a games newsletter.

# %%
playerdatatidy <- playerdata |>
mutate(playerdata, Age = as.integer(Age))

playerdatatidy|>
head(10)

summary(playerdatatidy)
# Out:
#    experience subscribe
# 1  Pro         TRUE
# 2  Veteran     TRUE
# 3  Veteran    FALSE
# 4  Amateur     TRUE
# 5  Regular     TRUE
# 6  Amateur     TRUE
# 7  Regular     TRUE
# 8  Amateur    FALSE
# 9  Amateur     TRUE
# 10 Veteran     TRUE
#    hashedEmail
# 1  f6daba428a5e19a3d47574858c13550499be23603422e6a0ee9728f8b53e192d
# 2  f3c813577c458ba0dfef80996f8f32c93b6e8af1fa939732842f2312358a88e9
# 3  b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3c5a9d2118eb7ccbb28
# 4  23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4fa7a5a659ff443a0eb5
# 5  7dc01f10bf20671ecfccdac23812b1b415acd42c2147cb0af4d48fcce2420f3e
# 6  f58aad5996a435f16b0284a3b267f973f9af99e7a89bee0430055a44fa92f977
# 7  8e594b8953193b26f498db95a508b03c6fe1c24bb5251d392c18a0da9a722807
# 8  1d2371d8a35c8831034b25bda8764539ab7db0f63938696917c447128a2540dd
# 9  8b71f4d66a38389b7528bb38ba6eb71157733df7d1740371852a797ae97d82d1
# 10 bbe2d83de678f519c4b3daa7265e683b4fe2d814077f9094afd11d8f217039ec
# ...

# %% [markdown]
# ***(3) Data Visualization***

# %%
options(repr.plot.width = 8, repr.plot.height = 8)

graph1 <- playerdatatidy|>
ggplot(aes(x = experience, y = played_hours, fill = experience))+
geom_bar(stat = "identity") +
labs(x = "Experience level", y = "Total Hours Played (Hrs)", fill = "Experience Level", title = "Total Hours Played vs Experience Level")+
theme(text = element_text(size = 15))


graph1
# Out:
# plot without title

# %%
graph2 <
# Out:
# Error in `ggplot_add()`:
# ! Can't add `graph2` to a <ggplot> object.
# Traceback:
#
# 1. `+.gg`(ggplot(playerdatatidy, aes(x = played_hours, y = Age,
#  .     color = experience)) + geom_point(alpha = 0.5) + facet_grid() +
#  .     labs(title = "Age vs. Played Hours, Broken Down by Experience Level",
#  .         subtitle = "Faceted plots separate data by experience for clear comparison.",
#  .         x = "Total Played Hours (h)", y = "Age (years)", color = "Experience"),
#  .     graph2)
# 2. add_ggplot(e1, e2, e2name)
# 3. ggplot_add(object, p, objectname)
# 4. ggplot_add.default(object, p, objectname)
# 5. cli::cli_abort("Can't add {.var {object_name}} to a {.cls ggplot} object.")
# 6. rlang::abort(message, ..., call = call, use_cli_format = TRUE,
#  .     .frame = .frame)
# 7. signal_abort(cnd, .file)
